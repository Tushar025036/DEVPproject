# %%
{
 "cells": [
  {
   "cell_type": "code",
   "execution_count": 1,
   "id": "a681b844",
   "metadata": {},
   "outputs": [],
   "source": [
    "#In this dataset, we are going to perform data Exploration and data visualization of the given dataset. Other things which can explore through it are as follow: -\n",
    "# Explatory Data Analysis\n",
    "# Determining characteristics affecting placement\n",
    "# Determining characteristics affecting salary\n",
    "# Common questions which can be answered through this dataset are: -\n",
    "# Does GPA affect placement?\n",
    "# Does Higher Secondary School's Percentage still affect campus placement?\n",
    "# Is work experience required for securing good job?\n",
    "# What factor affect the salary?"
   ]
  },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/507916271.py", line 20
#     },
#       ^
# SyntaxError: unexpected EOF while parsing

# %%
 {
   "cell_type": "code",
   "execution_count": 2,
   "id": "62b9eecf",
   "metadata": {},
   "outputs": [],
   "source": [
    "import numpy as np \n",
    "import pandas as pd \n",
    "import matplotlib.pyplot as plt\n",
    "import seaborn as sns\n",
    "import altair as alt"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 2,
#   'id': '62b9eecf',
#   'metadata': {},
#   'outputs': [],
#   'source': ['import numpy as np \n',
#    'import pandas as pd \n',
#    'import matplotlib.pyplot as plt\n',
#    'import seaborn as sns\n',
#    'import altair as alt']},)

# %%
  {
   "cell_type": "code",
   "execution_count": 3,
   "id": "5424d1b9",
   "metadata": {},
   "outputs": [],
   "source": [
    "df=pd.read_csv('18-Placement_Data_Full_Class.csv')"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 3,
#   'id': '5424d1b9',
#   'metadata': {},
#   'outputs': [],
#   'source': ["df=pd.read_csv('18-Placement_Data_Full_Class.csv')"]},)

# %%
  {
   "cell_type": "code",
   "execution_count": 4,
   "id": "ebb27beb",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/html": [
       "<div>\n",
       "<style scoped>\n",
       "    .dataframe tbody tr th:only-of-type {\n",
       "        vertical-align: middle;\n",
       "    }\n",
       "\n",
       "    .dataframe tbody tr th {\n",
       "        vertical-align: top;\n",
       "    }\n",
       "\n",
       "    .dataframe thead th {\n",
       "        text-align: right;\n",
       "    }\n",
       "</style>\n",
       "<table border=\"1\" class=\"dataframe\">\n",
       "  <thead>\n",
       "    <tr style=\"text-align: right;\">\n",
       "      <th></th>\n",
       "      <th>sl_no</th>\n",
       "      <th>gender</th>\n",
       "      <th>ssc_p</th>\n",
       "      <th>ssc_b</th>\n",
       "      <th>hsc_p</th>\n",
       "      <th>hsc_b</th>\n",
       "      <th>hsc_s</th>\n",
       "      <th>degree_p</th>\n",
       "      <th>degree_t</th>\n",
       "      <th>workex</th>\n",
       "      <th>etest_p</th>\n",
       "      <th>specialisation</th>\n",
       "      <th>mba_p</th>\n",
       "      <th>status</th>\n",
       "      <th>salary</th>\n",
       "    </tr>\n",
       "  </thead>\n",
       "  <tbody>\n",
       "    <tr>\n",
       "      <th>0</th>\n",
       "      <td>1</td>\n",
       "      <td>M</td>\n",
       "      <td>67.00</td>\n",
       "      <td>Others</td>\n",
       "      <td>91.00</td>\n",
       "      <td>Others</td>\n",
       "      <td>Commerce</td>\n",
       "      <td>58.00</td>\n",
       "      <td>Sci&amp;Tech</td>\n",
       "      <td>No</td>\n",
       "      <td>55.0</td>\n",
       "      <td>Mkt&amp;HR</td>\n",
       "      <td>58.80</td>\n",
       "      <td>Placed</td>\n",
       "      <td>270000.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>1</th>\n",
       "      <td>2</td>\n",
       "      <td>M</td>\n",
       "      <td>79.33</td>\n",
       "      <td>Central</td>\n",
       "      <td>78.33</td>\n",
       "      <td>Others</td>\n",
       "      <td>Science</td>\n",
       "      <td>77.48</td>\n",
       "      <td>Sci&amp;Tech</td>\n",
       "      <td>Yes</td>\n",
       "      <td>86.5</td>\n",
       "      <td>Mkt&amp;Fin</td>\n",
       "      <td>66.28</td>\n",
       "      <td>Placed</td>\n",
       "      <td>200000.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>2</th>\n",
       "      <td>3</td>\n",
       "      <td>M</td>\n",
       "      <td>65.00</td>\n",
       "      <td>Central</td>\n",
       "      <td>68.00</td>\n",
       "      <td>Central</td>\n",
       "      <td>Arts</td>\n",
       "      <td>64.00</td>\n",
       "      <td>Comm&amp;Mgmt</td>\n",
       "      <td>No</td>\n",
       "      <td>75.0</td>\n",
       "      <td>Mkt&amp;Fin</td>\n",
       "      <td>57.80</td>\n",
       "      <td>Placed</td>\n",
       "      <td>250000.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>3</th>\n",
       "      <td>4</td>\n",
       "      <td>M</td>\n",
       "      <td>56.00</td>\n",
       "      <td>Central</td>\n",
       "      <td>52.00</td>\n",
       "      <td>Central</td>\n",
       "      <td>Science</td>\n",
       "      <td>52.00</td>\n",
       "      <td>Sci&amp;Tech</td>\n",
       "      <td>No</td>\n",
       "      <td>66.0</td>\n",
       "      <td>Mkt&amp;HR</td>\n",
       "      <td>59.43</td>\n",
       "      <td>Not Placed</td>\n",
       "      <td>NaN</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>4</th>\n",
       "      <td>5</td>\n",
       "      <td>M</td>\n",
       "      <td>85.80</td>\n",
       "      <td>Central</td>\n",
       "      <td>73.60</td>\n",
       "      <td>Central</td>\n",
       "      <td>Commerce</td>\n",
       "      <td>73.30</td>\n",
       "      <td>Comm&amp;Mgmt</td>\n",
       "      <td>No</td>\n",
       "      <td>96.8</td>\n",
       "      <td>Mkt&amp;Fin</td>\n",
       "      <td>55.50</td>\n",
       "      <td>Placed</td>\n",
       "      <td>425000.0</td>\n",
       "    </tr>\n",
       "  </tbody>\n",
       "</table>\n",
       "</div>"
      ],
      "text/plain": [
       "   sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \\\n",
       "0      1      M  67.00   Others  91.00   Others  Commerce     58.00   \n",
       "1      2      M  79.33  Central  78.33   Others   Science     77.48   \n",
       "2      3      M  65.00  Central  68.00  Central      Arts     64.00   \n",
       "3      4      M  56.00  Central  52.00  Central   Science     52.00   \n",
       "4      5      M  85.80  Central  73.60  Central  Commerce     73.30   \n",
       "\n",
       "    degree_t workex  etest_p specialisation  mba_p      status    salary  \n",
       "0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0  \n",
       "1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0  \n",
       "2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0  \n",
       "3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN  \n",
       "4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0  "
      ]
     },
     "execution_count": 4,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "df.head()"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 4,
#   'id': 'ebb27beb',
#   'metadata': {},
#   'outputs': [{'data': {'text/html': ['<div>\n',
#       '<style scoped>\n',
#       '    .dataframe tbody tr th:only-of-type {\n',
#       '        vertical-align: middle;\n',
#       '    }\n',
#       '\n',
#       '    .dataframe tbody tr th {\n',
#       '        vertical-align: top;\n',
#       '    }\n',
#       '\n',
#       '    .dataframe thead th {\n',
#       '        text-align: right;\n',
#       '    }\n',
#       '</style>\n',
#       '<table border="1" class="dataframe">\n',
#       '  <thead>\n',
#       '    <tr style="text-align: right;">\n',
#       '      <th></th>\n',
#       '      <th>sl_no</th>\n',
#       '      <th>gender</th>\n',
#       '      <th>ssc_p</th>\n',
#       '      <th>ssc_b</th>\n',
#       '      <th>hsc_p</th>\n',
#       '      <th>hsc_b</th>\n',
#       '      <th>hsc_s</th>\n',
#       '      <th>degree_p</th>\n',
#       '      <th>degree_t</th>\n',
#       '      <th>workex</th>\n',
#       '      <th>etest_p</th>\n',
#       '      <th>specialisation</th>\n',
#       '      <th>mba_p</th>\n',
#       '      <th>status</th>\n',
#       '      <th>salary</th>\n',
#       '    </tr>\n',
#       '  </thead>\n',
#       '  <tbody>\n',
#       '    <tr>\n',
#       '      <th>0</th>\n',
#       '      <td>1</td>\n',
#       '      <td>M</td>\n',
#       '      <td>67.00</td>\n',
#       '      <td>Others</td>\n',
#       '      <td>91.00</td>\n',
#       '      <td>Others</td>\n',
#       '      <td>Commerce</td>\n',
#       '      <td>58.00</td>\n',
#       '      <td>Sci&amp;Tech</td>\n',
#       '      <td>No</td>\n',
#       '      <td>55.0</td>\n',
#       '      <td>Mkt&amp;HR</td>\n',
#       '      <td>58.80</td>\n',
#       '      <td>Placed</td>\n',
#       '      <td>270000.0</td>\n',
#       '    </tr>\n',
#       '    <tr>\n',
#       '      <th>1</th>\n',
#       '      <td>2</td>\n',
#       '      <td>M</td>\n',
#       '      <td>79.33</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>78.33</td>\n',
#       '      <td>Others</td>\n',
#       '      <td>Science</td>\n',
#       '      <td>77.48</td>\n',
#       '      <td>Sci&amp;Tech</td>\n',
#       '      <td>Yes</td>\n',
#       '      <td>86.5</td>\n',
#       '      <td>Mkt&amp;Fin</td>\n',
#       '      <td>66.28</td>\n',
#       '      <td>Placed</td>\n',
#       '      <td>200000.0</td>\n',
#       '    </tr>\n',
#       '    <tr>\n',
#       '      <th>2</th>\n',
#       '      <td>3</td>\n',
#       '      <td>M</td>\n',
#       '      <td>65.00</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>68.00</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>Arts</td>\n',
#       '      <td>64.00</td>\n',
#       '      <td>Comm&amp;Mgmt</td>\n',
#       '      <td>No</td>\n',
#       '      <td>75.0</td>\n',
#       '      <td>Mkt&amp;Fin</td>\n',
#       '      <td>57.80</td>\n',
#       '      <td>Placed</td>\n',
#       '      <td>250000.0</td>\n',
#       '    </tr>\n',
#       '    <tr>\n',
#       '      <th>3</th>\n',
#       '      <td>4</td>\n',
#       '      <td>M</td>\n',
#       '      <td>56.00</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>52.00</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>Science</td>\n',
#       '      <td>52.00</td>\n',
#       '      <td>Sci&amp;Tech</td>\n',
#       '      <td>No</td>\n',
#       '      <td>66.0</td>\n',
#       '      <td>Mkt&amp;HR</td>\n',
#       '      <td>59.43</td>\n',
#       '      <td>Not Placed</td>\n',
#       '      <td>NaN</td>\n',
#       '    </tr>\n',
#       '    <tr>\n',
#       '      <th>4</th>\n',
#       '      <td>5</td>\n',
#       '      <td>M</td>\n',
#       '      <td>85.80</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>73.60</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>Commerce</td>\n',
#       '      <td>73.30</td>\n',
#       '      <td>Comm&amp;Mgmt</td>\n',
#       '      <td>No</td>\n',
#       '      <td>96.8</td>\n',
#       '      <td>Mkt&amp;Fin</td>\n',
#       '      <td>55.50</td>\n',
#       '      <td>Placed</td>\n',
#       '      <td>425000.0</td>\n',
#       '    </tr>\n',
#       '  </tbody>\n',
#       '</table>\n',
#       '</div>'],
#      'text/plain': ['   sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \\\n',
#       '0      1      M  67.00   Others  91.00   Others  Commerce     58.00   \n',
#       '1      2      M  79.33  Central  78.33   Others   Science     77.48   \n',
#       '2      3      M  65.00  Central  68.00  Central      Arts     64.00   \n',
#       '3      4      M  56.00  Central  52.00  Central   Science     52.00   \n',
#       '4      5      M  85.80  Central  73.60  Central  Commerce     73.30   \n',
#       '\n',
#       '    degree_t workex  etest_p specialisation  mba_p      status    salary  \n',
#       '0   Sci&Tech     No     55.0         Mkt&HR  58.80      Placed  270000.0  \n',
#       '1   Sci&Tech    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0  \n',
#       '2  Comm&Mgmt     No     75.0        Mkt&Fin  57.80      Placed  250000.0  \n',
#       '3   Sci&Tech     No     66.0         Mkt&HR  59.43  Not Placed       NaN  \n',
#       '4  Comm&Mgmt     No     96.8        Mkt&Fin  55.50      Placed  425000.0  ']},
#     'execution_count': 4,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['df.head()']},)

# %%
 {
   "cell_type": "code",
   "execution_count": 5,
   "id": "1bebe594",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "(215, 15)"
      ]
     },
     "execution_count": 5,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "df.shape # Checking the number of rows and columns"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 5,
#   'id': '1bebe594',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ['(215, 15)']},
#     'execution_count': 5,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['df.shape # Checking the number of rows and columns']},)

# %%
  {
   "cell_type": "code",
   "execution_count": 6,
   "id": "c1879f2a",
   "metadata": {},
   "outputs": [],
   "source": [
    "#Remove Serial Number because it is not useful for analysis purpose\n",
    "df.drop(\"sl_no\", axis=1, inplace=True)"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 6,
#   'id': 'c1879f2a',
#   'metadata': {},
#   'outputs': [],
#   'source': ['#Remove Serial Number because it is not useful for analysis purpose\n',
#    'df.drop("sl_no", axis=1, inplace=True)']},)

# %%
  {
   "cell_type": "code",
   "execution_count": 7,
   "id": "ede52b6c",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/html": [
       "<div>\n",
       "<style scoped>\n",
       "    .dataframe tbody tr th:only-of-type {\n",
       "        vertical-align: middle;\n",
       "    }\n",
       "\n",
       "    .dataframe tbody tr th {\n",
       "        vertical-align: top;\n",
       "    }\n",
       "\n",
       "    .dataframe thead th {\n",
       "        text-align: right;\n",
       "    }\n",
       "</style>\n",
       "<table border=\"1\" class=\"dataframe\">\n",
       "  <thead>\n",
       "    <tr style=\"text-align: right;\">\n",
       "      <th></th>\n",
       "      <th>gender</th>\n",
       "      <th>ssc_p</th>\n",
       "      <th>ssc_b</th>\n",
       "      <th>hsc_p</th>\n",
       "      <th>hsc_b</th>\n",
       "      <th>hsc_s</th>\n",
       "      <th>degree_p</th>\n",
       "      <th>degree_t</th>\n",
       "      <th>workex</th>\n",
       "      <th>etest_p</th>\n",
       "      <th>specialisation</th>\n",
       "      <th>mba_p</th>\n",
       "      <th>status</th>\n",
       "      <th>salary</th>\n",
       "    </tr>\n",
       "  </thead>\n",
       "  <tbody>\n",
       "    <tr>\n",
       "      <th>0</th>\n",
       "      <td>M</td>\n",
       "      <td>67.00</td>\n",
       "      <td>Others</td>\n",
       "      <td>91.00</td>\n",
       "      <td>Others</td>\n",
       "      <td>Commerce</td>\n",
       "      <td>58.00</td>\n",
       "      <td>Sci&amp;Tech</td>\n",
       "      <td>No</td>\n",
       "      <td>55.0</td>\n",
       "      <td>Mkt&amp;HR</td>\n",
       "      <td>58.80</td>\n",
       "      <td>Placed</td>\n",
       "      <td>270000.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>1</th>\n",
       "      <td>M</td>\n",
       "      <td>79.33</td>\n",
       "      <td>Central</td>\n",
       "      <td>78.33</td>\n",
       "      <td>Others</td>\n",
       "      <td>Science</td>\n",
       "      <td>77.48</td>\n",
       "      <td>Sci&amp;Tech</td>\n",
       "      <td>Yes</td>\n",
       "      <td>86.5</td>\n",
       "      <td>Mkt&amp;Fin</td>\n",
       "      <td>66.28</td>\n",
       "      <td>Placed</td>\n",
       "      <td>200000.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>2</th>\n",
       "      <td>M</td>\n",
       "      <td>65.00</td>\n",
       "      <td>Central</td>\n",
       "      <td>68.00</td>\n",
       "      <td>Central</td>\n",
       "      <td>Arts</td>\n",
       "      <td>64.00</td>\n",
       "      <td>Comm&amp;Mgmt</td>\n",
       "      <td>No</td>\n",
       "      <td>75.0</td>\n",
       "      <td>Mkt&amp;Fin</td>\n",
       "      <td>57.80</td>\n",
       "      <td>Placed</td>\n",
       "      <td>250000.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>3</th>\n",
       "      <td>M</td>\n",
       "      <td>56.00</td>\n",
       "      <td>Central</td>\n",
       "      <td>52.00</td>\n",
       "      <td>Central</td>\n",
       "      <td>Science</td>\n",
       "      <td>52.00</td>\n",
       "      <td>Sci&amp;Tech</td>\n",
       "      <td>No</td>\n",
       "      <td>66.0</td>\n",
       "      <td>Mkt&amp;HR</td>\n",
       "      <td>59.43</td>\n",
       "      <td>Not Placed</td>\n",
       "      <td>NaN</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>4</th>\n",
       "      <td>M</td>\n",
       "      <td>85.80</td>\n",
       "      <td>Central</td>\n",
       "      <td>73.60</td>\n",
       "      <td>Central</td>\n",
       "      <td>Commerce</td>\n",
       "      <td>73.30</td>\n",
       "      <td>Comm&amp;Mgmt</td>\n",
       "      <td>No</td>\n",
       "      <td>96.8</td>\n",
       "      <td>Mkt&amp;Fin</td>\n",
       "      <td>55.50</td>\n",
       "      <td>Placed</td>\n",
       "      <td>425000.0</td>\n",
       "    </tr>\n",
       "  </tbody>\n",
       "</table>\n",
       "</div>"
      ],
      "text/plain": [
       "  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \\\n",
       "0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech   \n",
       "1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech   \n",
       "2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt   \n",
       "3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech   \n",
       "4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt   \n",
       "\n",
       "  workex  etest_p specialisation  mba_p      status    salary  \n",
       "0     No     55.0         Mkt&HR  58.80      Placed  270000.0  \n",
       "1    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0  \n",
       "2     No     75.0        Mkt&Fin  57.80      Placed  250000.0  \n",
       "3     No     66.0         Mkt&HR  59.43  Not Placed       NaN  \n",
       "4     No     96.8        Mkt&Fin  55.50      Placed  425000.0  "
      ]
     },
     "execution_count": 7,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "df.head()"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 7,
#   'id': 'ede52b6c',
#   'metadata': {},
#   'outputs': [{'data': {'text/html': ['<div>\n',
#       '<style scoped>\n',
#       '    .dataframe tbody tr th:only-of-type {\n',
#       '        vertical-align: middle;\n',
#       '    }\n',
#       '\n',
#       '    .dataframe tbody tr th {\n',
#       '        vertical-align: top;\n',
#       '    }\n',
#       '\n',
#       '    .dataframe thead th {\n',
#       '        text-align: right;\n',
#       '    }\n',
#       '</style>\n',
#       '<table border="1" class="dataframe">\n',
#       '  <thead>\n',
#       '    <tr style="text-align: right;">\n',
#       '      <th></th>\n',
#       '      <th>gender</th>\n',
#       '      <th>ssc_p</th>\n',
#       '      <th>ssc_b</th>\n',
#       '      <th>hsc_p</th>\n',
#       '      <th>hsc_b</th>\n',
#       '      <th>hsc_s</th>\n',
#       '      <th>degree_p</th>\n',
#       '      <th>degree_t</th>\n',
#       '      <th>workex</th>\n',
#       '      <th>etest_p</th>\n',
#       '      <th>specialisation</th>\n',
#       '      <th>mba_p</th>\n',
#       '      <th>status</th>\n',
#       '      <th>salary</th>\n',
#       '    </tr>\n',
#       '  </thead>\n',
#       '  <tbody>\n',
#       '    <tr>\n',
#       '      <th>0</th>\n',
#       '      <td>M</td>\n',
#       '      <td>67.00</td>\n',
#       '      <td>Others</td>\n',
#       '      <td>91.00</td>\n',
#       '      <td>Others</td>\n',
#       '      <td>Commerce</td>\n',
#       '      <td>58.00</td>\n',
#       '      <td>Sci&amp;Tech</td>\n',
#       '      <td>No</td>\n',
#       '      <td>55.0</td>\n',
#       '      <td>Mkt&amp;HR</td>\n',
#       '      <td>58.80</td>\n',
#       '      <td>Placed</td>\n',
#       '      <td>270000.0</td>\n',
#       '    </tr>\n',
#       '    <tr>\n',
#       '      <th>1</th>\n',
#       '      <td>M</td>\n',
#       '      <td>79.33</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>78.33</td>\n',
#       '      <td>Others</td>\n',
#       '      <td>Science</td>\n',
#       '      <td>77.48</td>\n',
#       '      <td>Sci&amp;Tech</td>\n',
#       '      <td>Yes</td>\n',
#       '      <td>86.5</td>\n',
#       '      <td>Mkt&amp;Fin</td>\n',
#       '      <td>66.28</td>\n',
#       '      <td>Placed</td>\n',
#       '      <td>200000.0</td>\n',
#       '    </tr>\n',
#       '    <tr>\n',
#       '      <th>2</th>\n',
#       '      <td>M</td>\n',
#       '      <td>65.00</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>68.00</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>Arts</td>\n',
#       '      <td>64.00</td>\n',
#       '      <td>Comm&amp;Mgmt</td>\n',
#       '      <td>No</td>\n',
#       '      <td>75.0</td>\n',
#       '      <td>Mkt&amp;Fin</td>\n',
#       '      <td>57.80</td>\n',
#       '      <td>Placed</td>\n',
#       '      <td>250000.0</td>\n',
#       '    </tr>\n',
#       '    <tr>\n',
#       '      <th>3</th>\n',
#       '      <td>M</td>\n',
#       '      <td>56.00</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>52.00</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>Science</td>\n',
#       '      <td>52.00</td>\n',
#       '      <td>Sci&amp;Tech</td>\n',
#       '      <td>No</td>\n',
#       '      <td>66.0</td>\n',
#       '      <td>Mkt&amp;HR</td>\n',
#       '      <td>59.43</td>\n',
#       '      <td>Not Placed</td>\n',
#       '      <td>NaN</td>\n',
#       '    </tr>\n',
#       '    <tr>\n',
#       '      <th>4</th>\n',
#       '      <td>M</td>\n',
#       '      <td>85.80</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>73.60</td>\n',
#       '      <td>Central</td>\n',
#       '      <td>Commerce</td>\n',
#       '      <td>73.30</td>\n',
#       '      <td>Comm&amp;Mgmt</td>\n',
#       '      <td>No</td>\n',
#       '      <td>96.8</td>\n',
#       '      <td>Mkt&amp;Fin</td>\n',
#       '      <td>55.50</td>\n',
#       '      <td>Placed</td>\n',
#       '      <td>425000.0</td>\n',
#       '    </tr>\n',
#       '  </tbody>\n',
#       '</table>\n',
#       '</div>'],
#      'text/plain': ['  gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p   degree_t  \\\n',
#       '0      M  67.00   Others  91.00   Others  Commerce     58.00   Sci&Tech   \n',
#       '1      M  79.33  Central  78.33   Others   Science     77.48   Sci&Tech   \n',
#       '2      M  65.00  Central  68.00  Central      Arts     64.00  Comm&Mgmt   \n',
#       '3      M  56.00  Central  52.00  Central   Science     52.00   Sci&Tech   \n',
#       '4      M  85.80  Central  73.60  Central  Commerce     73.30  Comm&Mgmt   \n',
#       '\n',
#       '  workex  etest_p specialisation  mba_p      status    salary  \n',
#       '0     No     55.0         Mkt&HR  58.80      Placed  270000.0  \n',
#       '1    Yes     86.5        Mkt&Fin  66.28      Placed  200000.0  \n',
#       '2     No     75.0        Mkt&Fin  57.80      Placed  250000.0  \n',
#       '3     No     66.0         Mkt&HR  59.43  Not Placed       NaN  \n',
#       '4     No     96.8        Mkt&Fin  55.50      Placed  425000.0  ']},
#     'execution_count': 7,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['df.head()']},)

# %%
  {
   "cell_type": "code",
   "execution_count": 8,
   "id": "2c2757fe",
   "metadata": {
    "scrolled": true
   },
   "outputs": [
    {
     "data": {
      "text/plain": [
       "0"
      ]
     },
     "execution_count": 8,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "# Checkinf for duplicate values\n",
    "df.duplicated().sum()     # We don't have any duplicated values"
   ]
  },
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_16808/3432861282.py in <module>
#       4  "id": "2c2757fe",
#       5  "metadata": {
# ----> 6   "scrolled": true
#       7  },
#       8  "outputs": [
#
# NameError: name 'true' is not defined

# %%
  {
   "cell_type": "code",
   "execution_count": 9,
   "id": "4457b6fe",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "gender             object\n",
       "ssc_p             float64\n",
       "ssc_b              object\n",
       "hsc_p             float64\n",
       "hsc_b              object\n",
       "hsc_s              object\n",
       "degree_p          float64\n",
       "degree_t           object\n",
       "workex             object\n",
       "etest_p           float64\n",
       "specialisation     object\n",
       "mba_p             float64\n",
       "status             object\n",
       "salary            float64\n",
       "dtype: object"
      ]
     },
     "execution_count": 9,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "df.dtypes     # Shows the data type of each variable"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 9,
#   'id': '4457b6fe',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ['gender             object\n',
#       'ssc_p             float64\n',
#       'ssc_b              object\n',
#       'hsc_p             float64\n',
#       'hsc_b              object\n',
#       'hsc_s              object\n',
#       'degree_p          float64\n',
#       'degree_t           object\n',
#       'workex             object\n',
#       'etest_p           float64\n',
#       'specialisation     object\n',
#       'mba_p             float64\n',
#       'status             object\n',
#       'salary            float64\n',
#       'dtype: object']},
#     'execution_count': 9,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['df.dtypes     # Shows the data type of each variable']},)

# %%
  {
   "cell_type": "code",
   "execution_count": 10,
   "id": "a623cec6",
   "metadata": {
    "scrolled": true
   },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/2519950760.py", line 7
#     },
#       ^
# SyntaxError: unexpected EOF while parsing

# %%
 {
     "data": {
      "text/html": [
       "<div>\n",
       "<style scoped>\n",
       "    .dataframe tbody tr th:only-of-type {\n",
       "        vertical-align: middle;\n",
       "    }\n",
       "\n",
       "    .dataframe tbody tr th {\n",
       "        vertical-align: top;\n",
       "    }\n",
       "\n",
       "    .dataframe thead th {\n",
       "        text-align: right;\n",
       "    }\n",
       "</style>\n",
       "<table border=\"1\" class=\"dataframe\">\n",
       "  <thead>\n",
       "    <tr style=\"text-align: right;\">\n",
       "      <th></th>\n",
       "      <th>ssc_p</th>\n",
       "      <th>hsc_p</th>\n",
       "      <th>degree_p</th>\n",
       "      <th>etest_p</th>\n",
       "      <th>mba_p</th>\n",
       "      <th>salary</th>\n",
       "    </tr>\n",
       "  </thead>\n",
       "  <tbody>\n",
       "    <tr>\n",
       "      <th>count</th>\n",
       "      <td>215.0</td>\n",
       "      <td>215.0</td>\n",
       "      <td>215.0</td>\n",
       "      <td>215.0</td>\n",
       "      <td>215.0</td>\n",
       "      <td>148.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>mean</th>\n",
       "      <td>67.0</td>\n",
       "      <td>66.0</td>\n",
       "      <td>66.0</td>\n",
       "      <td>72.0</td>\n",
       "      <td>62.0</td>\n",
       "      <td>288655.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>std</th>\n",
       "      <td>11.0</td>\n",
       "      <td>11.0</td>\n",
       "      <td>7.0</td>\n",
       "      <td>13.0</td>\n",
       "      <td>6.0</td>\n",
       "      <td>93457.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>min</th>\n",
       "      <td>41.0</td>\n",
       "      <td>37.0</td>\n",
       "      <td>50.0</td>\n",
       "      <td>50.0</td>\n",
       "      <td>51.0</td>\n",
       "      <td>200000.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>25%</th>\n",
       "      <td>61.0</td>\n",
       "      <td>61.0</td>\n",
       "      <td>61.0</td>\n",
       "      <td>60.0</td>\n",
       "      <td>58.0</td>\n",
       "      <td>240000.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>50%</th>\n",
       "      <td>67.0</td>\n",
       "      <td>65.0</td>\n",
       "      <td>66.0</td>\n",
       "      <td>71.0</td>\n",
       "      <td>62.0</td>\n",
       "      <td>265000.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>75%</th>\n",
       "      <td>76.0</td>\n",
       "      <td>73.0</td>\n",
       "      <td>72.0</td>\n",
       "      <td>84.0</td>\n",
       "      <td>66.0</td>\n",
       "      <td>300000.0</td>\n",
       "    </tr>\n",
       "    <tr>\n",
       "      <th>max</th>\n",
       "      <td>89.0</td>\n",
       "      <td>98.0</td>\n",
       "      <td>91.0</td>\n",
       "      <td>98.0</td>\n",
       "      <td>78.0</td>\n",
       "      <td>940000.0</td>\n",
       "    </tr>\n",
       "  </tbody>\n",
       "</table>\n",
       "</div>"
      ],
      "text/plain": [
       "       ssc_p  hsc_p  degree_p  etest_p  mba_p    salary\n",
       "count  215.0  215.0     215.0    215.0  215.0     148.0\n",
       "mean    67.0   66.0      66.0     72.0   62.0  288655.0\n",
       "std     11.0   11.0       7.0     13.0    6.0   93457.0\n",
       "min     41.0   37.0      50.0     50.0   51.0  200000.0\n",
       "25%     61.0   61.0      61.0     60.0   58.0  240000.0\n",
       "50%     67.0   65.0      66.0     71.0   62.0  265000.0\n",
       "75%     76.0   73.0      72.0     84.0   66.0  300000.0\n",
       "max     89.0   98.0      91.0     98.0   78.0  940000.0"
      ]
     },
     "execution_count": 10,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "df.describe().round()  # Gives the statistical Summary of the numeric variables in a dataset"
   ]
  },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/741055968.py", line 123
#     ],
#     ^
# IndentationError: unexpected indent

# %%
 {
   "cell_type": "code",
   "execution_count": 11,
   "id": "07bd0b70",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',\n",
       "       'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',\n",
       "       'salary'],\n",
       "      dtype='object')"
      ]
     },
     "execution_count": 11,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "#finding columns names in the dataset\n",
    "df.columns"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 11,
#   'id': '07bd0b70',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ["Index(['gender', 'ssc_p', 'ssc_b', 'hsc_p', 'hsc_b', 'hsc_s', 'degree_p',\n",
#       "       'degree_t', 'workex', 'etest_p', 'specialisation', 'mba_p', 'status',\n",
#       "       'salary'],\n",
#       "      dtype='object')"]},
#     'execution_count': 11,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['#finding columns names in the dataset\n', 'df.columns']},)

# %%
  {
   "cell_type": "code",
   "execution_count": 12,
   "id": "72641cf5",
   "metadata": {},
   "outputs": [
    {
     "name": "stdout",
     "output_type": "stream",
     "text": [
      "['Others' 'Central']\n",
      "['Others' 'Central']\n",
      "['Commerce' 'Science' 'Arts']\n",
      "['Sci&Tech' 'Comm&Mgmt' 'Others']\n",
      "['No' 'Yes']\n",
      "['Mkt&HR' 'Mkt&Fin']\n",
      "['Placed' 'Not Placed']\n"
     ]
    }
   ],
   "source": [
    "# Looking for the unique values of Categorical Features in the dataset\n",
    "print(df['ssc_b'].unique())\n",
    "print(df['hsc_b'].unique())\n",
    "print(df['hsc_s'].unique())\n",
    "print(df['degree_t'].unique())\n",
    "print(df['workex'].unique())\n",
    "print(df['specialisation'].unique())\n",
    "print(df['status'].unique())"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 12,
#   'id': '72641cf5',
#   'metadata': {},
#   'outputs': [{'name': 'stdout',
#     'output_type': 'stream',
#     'text': ["['Others' 'Central']\n",
#      "['Others' 'Central']\n",
#      "['Commerce' 'Science' 'Arts']\n",
#      "['Sci&Tech' 'Comm&Mgmt' 'Others']\n",
#      "['No' 'Yes']\n",
#      "['Mkt&HR' 'Mkt&Fin']\n",
#      "['Placed' 'Not Placed']\n"]}],
#   'source': ['# Looking for the unique values of Categorical Features in the dataset\n',
#    "print(df['ssc_b'].unique())\n",
#    "print(df['hsc_b'].unique())\n",
#    "print(df['hsc_s'].unique())\n",
#    "print(df['degree_t'].unique())\n",
#    "print(df['workex'].unique())\n",
#    "print(df['specialisation'].unique())\n",
#    "print(df['status'].unique())"]},)

# %%
  {
   "cell_type": "code",
   "execution_count": 13,
   "id": "260492cc",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "gender             0\n",
       "ssc_p              0\n",
       "ssc_b              0\n",
       "hsc_p              0\n",
       "hsc_b              0\n",
       "hsc_s              0\n",
       "degree_p           0\n",
       "degree_t           0\n",
       "workex             0\n",
       "etest_p            0\n",
       "specialisation     0\n",
       "mba_p              0\n",
       "status             0\n",
       "salary            67\n",
       "dtype: int64"
      ]
     },
     "execution_count": 13,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "#Checking Null values\n",
    "df.isnull().sum()      "
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 13,
#   'id': '260492cc',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ['gender             0\n',
#       'ssc_p              0\n',
#       'ssc_b              0\n',
#       'hsc_p              0\n',
#       'hsc_b              0\n',
#       'hsc_s              0\n',
#       'degree_p           0\n',
#       'degree_t           0\n',
#       'workex             0\n',
#       'etest_p            0\n',
#       'specialisation     0\n',
#       'mba_p              0\n',
#       'status             0\n',
#       'salary            67\n',
#       'dtype: int64']},
#     'execution_count': 13,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['#Checking Null values\n', 'df.isnull().sum()      ']},)

# %%
  {
   "cell_type": "code",
   "execution_count": 14,
   "id": "6bf96d7d",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Salary variable has 67 null values\n",
    "# So, we had made a separate dataframe for not null values in all columns for the purpose of data exploration.\n",
    "null_salary_data = df[df['salary'].notna()]\n",
    "null_salary_data = null_salary_data.reset_index(drop = True)"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 14,
#   'id': '6bf96d7d',
#   'metadata': {},
#   'outputs': [],
#   'source': ['# Salary variable has 67 null values\n',
#    '# So, we had made a separate dataframe for not null values in all columns for the purpose of data exploration.\n',
#    "null_salary_data = df[df['salary'].notna()]\n",
#    'null_salary_data = null_salary_data.reset_index(drop = True)']},)

# %%
 {
   "cell_type": "code",
   "execution_count": 15,
   "id": "2308e95d",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "M    139\n",
       "F     76\n",
       "Name: gender, dtype: int64"
      ]
     },
     "execution_count": 15,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "#Finding out total number of Males and females in the dataset\n",
    "df['gender'].value_counts()  #There are 139 Males and 76 Females "
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 15,
#   'id': '2308e95d',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ['M    139\n',
#       'F     76\n',
#       'Name: gender, dtype: int64']},
#     'execution_count': 15,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['#Finding out total number of Males and females in the dataset\n',
#    "df['gender'].value_counts()  #There are 139 Males and 76 Females "]},)

# %%
 {
   "cell_type": "code",
   "execution_count": 16,
   "id": "b72c4b57",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "Central    116\n",
       "Others      99\n",
       "Name: ssc_b, dtype: int64"
      ]
     },
     "execution_count": 16,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "# Finding out total number of students who were from Central Board  and from other Board in 10th standard in this dataset. \n",
    "df['ssc_b'].value_counts() # Hence, 116 Students were from Central Board and 99 students were from other boards in 10th Class "
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 16,
#   'id': 'b72c4b57',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ['Central    116\n',
#       'Others      99\n',
#       'Name: ssc_b, dtype: int64']},
#     'execution_count': 16,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['# Finding out total number of students who were from Central Board  and from other Board in 10th standard in this dataset. \n',
#    "df['ssc_b'].value_counts() # Hence, 116 Students were from Central Board and 99 students were from other boards in 10th Class "]},)

# %%
 {
   "cell_type": "code",
   "execution_count": 17,
   "id": "ac853a3f",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "Others     131\n",
       "Central     84\n",
       "Name: hsc_b, dtype: int64"
      ]
     },
     "execution_count": 17,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "# Finding out total number of students who were from Central Board  and from other Board in 12th standard in this dataset.\n",
    "df['hsc_b'].value_counts() # Hence, Only 84 Students were from Central Board and 131 are from others Boards in 12th Class"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 17,
#   'id': 'ac853a3f',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ['Others     131\n',
#       'Central     84\n',
#       'Name: hsc_b, dtype: int64']},
#     'execution_count': 17,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['# Finding out total number of students who were from Central Board  and from other Board in 12th standard in this dataset.\n',
#    "df['hsc_b'].value_counts() # Hence, Only 84 Students were from Central Board and 131 are from others Boards in 12th Class"]},)

# %%
 {
   "cell_type": "code",
   "execution_count": 18,
   "id": "890243fd",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "Commerce    113\n",
       "Science      91\n",
       "Arts         11\n",
       "Name: hsc_s, dtype: int64"
      ]
     },
     "execution_count": 18,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "# Finding out total number of students who have opted for science, commerece and arts in 12th standard in this dataset.\n",
    "df['hsc_s'].value_counts() # Hence, 113 students taken Commerce as compared to 91 science and 11 Arts"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 18,
#   'id': '890243fd',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ['Commerce    113\n',
#       'Science      91\n',
#       'Arts         11\n',
#       'Name: hsc_s, dtype: int64']},
#     'execution_count': 18,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['# Finding out total number of students who have opted for science, commerece and arts in 12th standard in this dataset.\n',
#    "df['hsc_s'].value_counts() # Hence, 113 students taken Commerce as compared to 91 science and 11 Arts"]},)

# %%
  {
   "cell_type": "code",
   "execution_count": 19,
   "id": "61db9b5f",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "No     141\n",
       "Yes     74\n",
       "Name: workex, dtype: int64"
      ]
     },
     "execution_count": 19,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "# Finding out total number of students who have work experience and who did'nt have work experience in this dataset.\n",
    "df['workex'].value_counts() # Therfore, Maximum of 141 students didn't have Experience as compared to 74 Experienced"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 19,
#   'id': '61db9b5f',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ['No     141\n',
#       'Yes     74\n',
#       'Name: workex, dtype: int64']},
#     'execution_count': 19,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ["# Finding out total number of students who have work experience and who did'nt have work experience in this dataset.\n",
#    "df['workex'].value_counts() # Therfore, Maximum of 141 students didn't have Experience as compared to 74 Experienced"]},)

# %%
 {
   "cell_type": "code",
   "execution_count": 20,
   "id": "3df421cd",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "Mkt&Fin    120\n",
       "Mkt&HR      95\n",
       "Name: specialisation, dtype: int64"
      ]
     },
     "execution_count": 20,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "# Finding out total number of students who have specialization in Marketing-finance or Marketing-HR in this dataset.\n",
    "df['specialisation'].value_counts() # There are 120 students have Specialization in Marketing-finance and 95 in Marketing-HR"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 20,
#   'id': '3df421cd',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ['Mkt&Fin    120\n',
#       'Mkt&HR      95\n',
#       'Name: specialisation, dtype: int64']},
#     'execution_count': 20,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['# Finding out total number of students who have specialization in Marketing-finance or Marketing-HR in this dataset.\n',
#    "df['specialisation'].value_counts() # There are 120 students have Specialization in Marketing-finance and 95 in Marketing-HR"]},)

# %%
  {
   "cell_type": "code",
   "execution_count": 21,
   "id": "5f77b6fb",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "text/plain": [
       "Placed        148\n",
       "Not Placed     67\n",
       "Name: status, dtype: int64"
      ]
     },
     "execution_count": 21,
     "metadata": {},
     "output_type": "execute_result"
    }
   ],
   "source": [
    "# Finding out total number of students who have got placed or not in a company in this dataset.\n",
    "df['status'].value_counts() # 148 students got placed as compared to 67 not placed students"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 21,
#   'id': '5f77b6fb',
#   'metadata': {},
#   'outputs': [{'data': {'text/plain': ['Placed        148\n',
#       'Not Placed     67\n',
#       'Name: status, dtype: int64']},
#     'execution_count': 21,
#     'metadata': {},
#     'output_type': 'execute_result'}],
#   'source': ['# Finding out total number of students who have got placed or not in a company in this dataset.\n',
#    "df['status'].value_counts() # 148 students got placed as compared to 67 not placed students"]},)

# %%
  {
   "cell_type": "code",
   "execution_count": 22,
   "id": "153e385d",
   "metadata": {},
   "outputs": [
    {
     "name": "stderr",
     "output_type": "stream",
     "text": [
      "C:\\ProgramData\\Anaconda31\\lib\\site-packages\\seaborn\\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
      "  warnings.warn(\n"
     ]
    },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/754752390.py", line 14
#     },
#       ^
# SyntaxError: unexpected EOF while parsing

# %%
    {
     "data": {
      "image/png": "...\n",
      "text/plain": [
       "<Figure size 432x288 with 1 Axes>"
      ]
     },
     "metadata": {
      "needs_background": "light"
     },
     "output_type": "display_data"
    }
   ],
   "source": [
    "# Does gender affect placements in this particular dataset?\n",
    "sns.countplot(\"gender\", hue=\"status\", data=df)\n",
    "plt.show()"
   ]
  },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/448731796.py", line 13
#     ],
#     ^
# IndentationError: unexpected indent

# %%
  {
   "cell_type": "code",
   "execution_count": 23,
   "id": "15e2cb12",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "image/png": "...\n",
      "text/plain": [
       "<Figure size 432x288 with 1 Axes>"
      ]
     },
     "metadata": {
      "needs_background": "light"
     },
     "output_type": "display_data"
    }
   ],
   "source": [
    "#This plot ignores NaN values for salary, igoring students who are not placed\n",
    "sns.kdeplot(df.salary[ df.gender==\"M\"])\n",
    "sns.kdeplot(df.salary[ df.gender==\"F\"])\n",
    "plt.legend([\"Male\", \"Female\"])\n",
    "plt.xlabel(\"Salary(100k)\")\n",
    "plt.show()"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 23,
#   'id': '15e2cb12',
#   'metadata': {},
#   'outputs': [{'data': {'image/png': '...\n',
#      'text/plain': ['<Figure size 432x288 with 1 Axes>']},
#     'metadata': {'needs_background': 'light'},
#     'output_type': 'display_data'}],
#   'source': ['#This plot ignores NaN values for salary, igoring students who are not placed\n',
#    'sns.kdeplot(df.salary[ df.gender=="M"])\n',
#    'sns.kdeplot(df.salary[ df.gender=="F"])\n',
#    'plt.legend(["Male", "Female"])\n',
#    'plt.xlabel("Salary(100k)")\n',
#    'plt.show()']},)

# %%
  {
   "cell_type": "code",
   "execution_count": 24,
   "id": "f29a5ccd",
   "metadata": {},
   "outputs": [
    {
     "name": "stderr",
     "output_type": "stream",
     "text": [
      "C:\\ProgramData\\Anaconda31\\lib\\site-packages\\seaborn\\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
      "  warnings.warn(\n"
     ]
    },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/549684701.py", line 14
#     },
#       ^
# SyntaxError: unexpected EOF while parsing

# %%
   {
     "data": {
      "image/png": "...\n",
      "text/plain": [
       "<Figure size 1296x432 with 1 Axes>"
      ]
     },
     "metadata": {
      "needs_background": "light"
     },
     "output_type": "display_data"
    }
   ],
   "source": [
    "plt.figure(figsize =(18,6))\n",
    "sns.boxplot(\"salary\", \"gender\", data=df)\n",
    "plt.show()"
   ]
  },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/1501265806.py", line 13
#     ],
#     ^
# SyntaxError: unmatched ']'

# %%
  {
   "cell_type": "code",
   "execution_count": 25,
   "id": "ba81d74e",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Analysis of the data to answer the above stated question are as follow: -\n",
    "# 30 Female and 40 Male students are not placed. Male students have comparatively higher placemets.\n",
    "# More outliers on Male -> Male students are getting high CTC jobs.\n",
    "# Male students are offered slightly greater salary than female on an average."
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 25,
#   'id': 'ba81d74e',
#   'metadata': {},
#   'outputs': [],
#   'source': ['# Analysis of the data to answer the above stated question are as follow: -\n',
#    '# 30 Female and 40 Male students are not placed. Male students have comparatively higher placemets.\n',
#    '# More outliers on Male -> Male students are getting high CTC jobs.\n',
#    '# Male students are offered slightly greater salary than female on an average.']},)

# %%
  {
   "cell_type": "code",
   "execution_count": 26,
   "id": "32664218",
   "metadata": {},
   "outputs": [
    {
     "data": {
      "image/png": "...\n",
      "text/plain": [
       "<Figure size 432x288 with 1 Axes>"
      ]
     },
     "metadata": {
      "needs_background": "light"
     },
     "output_type": "display_data"
    }
   ],
   "source": [
    "#Does Secondary Education affect placements in this dataset?\n",
    "sns.kdeplot(df.ssc_p[ df.status==\"Placed\"])\n",
    "sns.kdeplot(df.ssc_p[ df.status==\"Not Placed\"])\n",
    "plt.legend([\"Placed\", \"Not Placed\"])\n",
    "plt.xlabel(\"Secondary Education Percentage\")\n",
    "plt.show()"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 26,
#   'id': '32664218',
#   'metadata': {},
#   'outputs': [{'data': {'image/png': '...\n',
#      'text/plain': ['<Figure size 432x288 with 1 Axes>']},
#     'metadata': {'needs_background': 'light'},
#     'output_type': 'display_data'}],
#   'source': ['#Does Secondary Education affect placements in this dataset?\n',
#    'sns.kdeplot(df.ssc_p[ df.status=="Placed"])\n',
#    'sns.kdeplot(df.ssc_p[ df.status=="Not Placed"])\n',
#    'plt.legend(["Placed", "Not Placed"])\n',
#    'plt.xlabel("Secondary Education Percentage")\n',
#    'plt.show()']},)

# %%
  {
   "cell_type": "code",
   "execution_count": 27,
   "id": "fb912174",
   "metadata": {},
   "outputs": [
    {
     "name": "stderr",
     "output_type": "stream",
     "text": [
      "C:\\ProgramData\\Anaconda31\\lib\\site-packages\\seaborn\\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
      "  warnings.warn(\n"
     ]
    },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/3573371522.py", line 14
#     },
#       ^
# SyntaxError: unexpected EOF while parsing

# %%
 {
     "data": {
      "image/png": "...\n",
      "text/plain": [
       "<Figure size 432x288 with 1 Axes>"
      ]
     },
     "metadata": {
      "needs_background": "light"
     },
     "output_type": "display_data"
    }
   ],
   "source": [
    "sns.countplot(\"ssc_b\", hue=\"status\", data=df)\n",
    "plt.show()"
   ]
  },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/2050796948.py", line 13
#     ],
#     ^
# IndentationError: unexpected indent

# %%
  {
   "cell_type": "code",
   "execution_count": 28,
   "id": "126cb68e",
   "metadata": {},
   "outputs": [
    {
     "name": "stderr",
     "output_type": "stream",
     "text": [
      "C:\\ProgramData\\Anaconda31\\lib\\site-packages\\seaborn\\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
      "  warnings.warn(\n"
     ]
    },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/4012600194.py", line 14
#     },
#       ^
# SyntaxError: unexpected EOF while parsing

# %%
   {
     "data": {
      "image/png": "...\n",
      "text/plain": [
       "<Figure size 1296x432 with 1 Axes>"
      ]
     },
     "metadata": {
      "needs_background": "light"
     },
     "output_type": "display_data"
    }
   ],
   "source": [
    "plt.figure(figsize =(18,6))\n",
    "sns.boxplot(\"salary\", \"ssc_b\", data=df, color='m')\n",
    "plt.show()"
   ]
  },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/4211464117.py", line 13
#     ],
#     ^
# SyntaxError: unmatched ']'

# %%
   "cell_type": "code",
   "execution_count": 29,
   "id": "9b0f7204",
   "metadata": {},
   "outputs": [
    {
     "name": "stderr",
     "output_type": "stream",
     "text": [
      "C:\\ProgramData\\Anaconda31\\lib\\site-packages\\seaborn\\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.\n",
      "  warnings.warn(\n"
     ]
    },
# Out:
#   File "C:\Users\abhis\AppData\Local\Temp/ipykernel_16808/593296438.py", line 1
#     "cell_type": "code",
#     ^
# SyntaxError: illegal target for annotation

# %%
  {
   "cell_type": "code",
   "execution_count": 30,
   "id": "8c590121",
   "metadata": {},
   "outputs": [],
   "source": [
    "# Analysis of the data to answer the above stated question are as follow: -\n",
    "# All students with Secondary Education Percentage above 90% are placed\n",
    "# All students with Secondary Education Percentage below 50% are not-placed\n",
    "# Students with good Secondary Education Percentage are placed on average.\n",
    "# Board Of Education does not affect Placement Status much.\n",
    "# No specific pattern (correlation) between Secondary Education Percentage and Salary.\n",
    "# Board of Education is Not Affecting Salary"
   ]
  },
# Out:
# ({'cell_type': 'code',
#   'execution_count': 30,
#   'id': '8c590121',
#   'metadata': {},
#   'outputs': [],
#   'source': ['# Analysis of the data to answer the above stated question are as follow: -\n',
#    '# All students with Secondary Education Percentage above 90% are placed\n',
#    '# All students with Secondary Education Percentage below 50% are not-placed\n',
#    '# Students with good Secondary Education Percentage are placed on average.\n',
#    '# Board Of Education does not affect Placement Status much.\n',
#    '# No specific pattern (correlation) between Secondary Education Percentage and Salary.\n',
#    '# Board of Education is Not Affecting Salary']},)
